# %%
# !pip install git+https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")
parrot=Parrot(model_tag="Prithivida/parrot_paraphraser_on_T5",use_gpu=False)
# Out:
# Collecting git+https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git
#   Cloning https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git to /tmp/pip-req-build-f2wm3czj
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git /tmp/pip-req-build-f2wm3czj
#   Resolved https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git to commit 720a87a1ee557d8ed8d9a021adbdd1dd5616c5f9
#   Preparing metadata (setup.py) ... done
# Collecting transformers (from parrot==1.0)
#   Downloading transformers-4.33.3-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 24.1 MB/s eta 0:00:00
# Collecting sentencepiece (from parrot==1.0)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.0 MB/s eta 0:00:00
# Collecting python-Levenshtein (from parrot==1.0)
#   Downloading python_Levenshtein-0.22.0-py3-none-any.whl (9.4 kB)
# Collecting sentence-transformers (from parrot==1.0)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fuzzywuzzy (from parrot==1.0)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting Levenshtein==0.22.0 (from python-Levenshtein->parrot==1.0)
#   Downloading Levenshtein-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.9/172.9 kB 22.0 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein==0.22.0->python-Levenshtein->parrot==1.0)
#   Downloading rapidfuzz-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (1.11.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (3.8.1)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers->parrot==1.0)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (3.12.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->parrot==1.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.2 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->parrot==1.0)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->parrot==1.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->parrot==1.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->parrot==1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->parrot==1.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->parrot==1.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->parrot==1.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->parrot==1.0) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->parrot==1.0) (16.0.6)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->parrot==1.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->parrot==1.0) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->parrot==1.0) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers->parrot==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers->parrot==1.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers->parrot==1.0) (1.3.0)
# Building wheels for collected packages: parrot, sentence-transformers
#   Building wheel for parrot (setup.py) ... done
#   Created wheel for parrot: filename=parrot-1.0-py3-none-any.whl size=8590 sha256=0cc9f84229f52b7c45097c9ab7e4ae6f3f8ea134a0154d8b8d13e260cfd94c7e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e4yrwali/wheels/e8/ee/2a/4d6a4b2a5c37f5f750e90fa79d2ad84f444fba9b050ecbbe6d
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=018b61364cd5a901e0e0fbc183c74061687ace5272022fe5a1ad29f131b1d2c9
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built parrot sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, fuzzywuzzy, rapidfuzz, Levenshtein, huggingface-hub, transformers, python-Levenshtein, sentence-transformers, parrot
# Successfully installed Levenshtein-0.22.0 fuzzywuzzy-0.18.0 huggingface-hub-0.17.3 parrot-1.0 python-Levenshtein-0.22.0 rapidfuzz-3.3.1 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.3
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. If you see this, DO NOT PANIC! This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/913 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/476 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)2b9e5/.gitattributes:   0%|          | 0.00/736 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)3c1ed2b9e5/README.md:   0%|          | 0.00/3.74k [00:00<?, ?B/s]
# Downloading (…)1ed2b9e5/config.json:   0%|          | 0.00/686 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading (…)c1ed2b9e5/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)2b9e5/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading (…)c1ed2b9e5/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)ed2b9e5/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
def print_paraphrase_sentences(phrases):
  for phrase in phrases:
      print("-"*100)
      print("Input_phrase: ", phrase)
      print("-"*100)
      para_phrases = parrot.augment(input_phrase=phrase, use_gpu=False)
      print(para_phrases)
      for para_phrase in para_phrases:
        print(para_phrase)

# %%
phrases= ["What are the famous places we should not miss in Russia?","Can you recommend some upscale restaurants in Newyork?"]
print_paraphrase_sentences(phrases)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  What are the famous places we should not miss in Russia?
# ----------------------------------------------------------------------------------------------------
# [('what should i not miss while visiting russia?', 43), ("show some places we can't miss in russia?", 35), ('which are the places you cant miss in russia?', 30)]
# ('what should i not miss while visiting russia?', 43)
# ("show some places we can't miss in russia?", 35)
# ('which are the places you cant miss in russia?', 30)
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  Can you recommend some upscale restaurants in Newyork?
# ----------------------------------------------------------------------------------------------------
# [('recommend some good restaurants in newyork?', 27), ('can you list the upscale restaurants in new york?', 25), ('can you list the best upscale restaurants in newyork?', 25), ('can you recommend some upscale restaurants in new york?', 13)]
# ('recommend some good restaurants in newyork?', 27)
# ('can you list the upscale restaurants in new york?', 25)
# ('can you list the best upscale restaurants in newyork?', 25)
# ('can you recommend some upscale restaurants in new york?', 13)

# %%
def custom_paraphrase_sentences(phrase, phrase_diversity=False):
    print("-" * 100)
    print("Input_phrase: ", phrase)
    print("-" * 100)
    para_phrases = parrot.augment(input_phrase=phrase, use_gpu=False,
                                  diversity_ranker="levenshtein",
                                  max_return_phrases=15,
                                  do_diverse=False,
                                  max_length=40,
                                  adequacy_threshold=0.85,
                                  fluency_threshold=0.88)
    for para_phrase in para_phrases:
        print(para_phrase)

# %%
diversity_phrases=["Which is better for the lats? Pull-ups or Lat Pull down?"]

# %%
custom_paraphrase_sentences(diversity_phrases[0])
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  Which is better for the lats? Pull-ups or Lat Pull down?
# ----------------------------------------------------------------------------------------------------
# ('tell me the difference between pull-ups and lat pull downs?', 37)
# ('which are best lean pull-ups or lat pull-downs?', 31)
# ('what is better for lat pullups or pull-downs?', 28)
# ('which is better for lats pull ups or pull downs?', 23)
# ("what's better for the lats pull-ups or lat pull down?", 18)

# %%
phrase_diversity= True
custom_paraphrase_sentence(diversity_phrases[0],phrase_diversity)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  Which is better for the lats? Pull-ups or Lat Pull down?
# ----------------------------------------------------------------------------------------------------
# ('can pull ups or lat pull downs really work for the lats?', 53)
# ('should lats be pulled up or held down?', 46)
# ('is it better to pull-ups or a pull down for the lats?', 44)
# ('tell me the best workout for lats? pull-ups or lat pull down?', 28)
# ('which is better to pull ups or lat pull downs?', 26)
# ("what's better for the lats - pull-up or pull down?", 24)
# ('tell me the best fit pose for the lats? pull-ups or lat pull-down?', 24)

# %%
while True:
  user_q = input("Enter a phrase (To quit enter 'exit'): ")
  if user_q == "exit":
    break
  else:
    phrase_d = input("Do you want phrasal diversity? (y or n): ")
    if phrase_d and phrase_d.lower() == "y":
      custom_paraphrase_sentences(user_q, phrase_diversity=True)
    else:
        custom_paraphrase_sentences(user_q)
# Out:
# Enter a phrase (To quit enter 'exit'): which is better books or tabs
# Do you want phrasal diversity? (y or n): n
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  which is better books or tabs
# ----------------------------------------------------------------------------------------------------
# ('which books are better?', 30)
# Enter a phrase (To quit enter 'exit'): how to be astronaut
# Do you want phrasal diversity? (y or n): n
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  how to be astronaut
# ----------------------------------------------------------------------------------------------------
# ('how do i become a good astronaut?', 21)
# ('how could i become an astronaut?', 20)
# ('how do i become an astronaut?', 20)
# ('how can i become an astronaut?', 19)
# ('how to become an astronaut?', 19)
# ('how to become a astronaut?', 19)
# ('how can i become an astronaut', 18)
# ('how to become an astronaut', 18)
# ('how can i become a astronaut', 18)
# ('how can you be an astronaut?', 17)
# ('how to be an astronaut', 15)
# ('how to be astronaut', 12)
# Enter a phrase (To quit enter 'exit'): how to read books
# Do you want phrasal diversity? (y or n): y
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  how to read books
# ----------------------------------------------------------------------------------------------------
# ('how to read books', 12)
# Enter a phrase (To quit enter 'exit'): how to read book
# Do you want phrasal diversity? (y or n): n
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  how to read book
# ----------------------------------------------------------------------------------------------------
# ('how do i read a book?', 17)
# ('how can i read books', 16)
# ('how to read a book', 14)
# ('how to read books', 13)
# Enter a phrase (To quit enter 'exit'): how to read book
# Do you want phrasal diversity? (y or n): y
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  how to read book
# ----------------------------------------------------------------------------------------------------
# ('how can i read a book?', 18)
# ('how do i read a book?', 17)
# ('how to read a book?', 15)
# ('how to read a book', 15)
# ('how to read a book -', 15)
# Enter a phrase (To quit enter 'exit'): how to tie a tie
# Do you want phrasal diversity? (y or n): y
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  how to tie a tie
# ----------------------------------------------------------------------------------------------------
# ('how can i tie a knot?', 20)
# ('how do you tie it?', 18)
# ('how to tie it?', 16)
# ('how do you tie a tie?', 15)
# ('how to tie a tie?', 13)
# ('how to tie a tie', 12)
